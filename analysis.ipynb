# %% [markdown]
# # Techno Alnaysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Complete_Techno_Sales_Data.csv")

# %%
data.isnull().sum()
# Out:
# Order_Number           0
# State_Code             0
# Customer_Name          0
# Order_Date             0
# Status                 0
# Product                0
# Category               0
# Brand                  0
# Cost_product           0
# Sales                  0
# Quantity               0
# Total_Cost             0
# Total_Sales            0
# Total_Profit           0
# Assigned Supervisor    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Total Sales

# %%
data['Total_Profit'].sum()
# Out:
# np.int64(22914933)

# %% [markdown]
# ### Total Sales

# %%
data['Total_Sales'].sum()
# Out:
# np.int64(99298043)

# %% [markdown]
# ### Total Cost of sales

# %%
data['Total_Cost'].sum()
# Out:
# np.int64(76383110)

# %% [markdown]
# ### Total Quantity

# %%
data['Quantity'].sum()
# Out:
# np.int64(12671)

# %% [markdown]
# ### Total Customers

# %%
data['Customer_Name'].count()
# Out:
# np.int64(5095)

# %%
data['Status'].unique()
# Out:
# array(['Delivered', 'Order', 'Processing', 'Shipped'], dtype=object)

# %% [markdown]
# ### Total Sales Assigned Supervisor

# %%
data.groupby('Assigned Supervisor')['Total_Sales'].sum()
# Out:
# Assigned Supervisor
# Aadil Khan      15730767
# Aarvi Gupta     18685368
# Advika Joshi    15253693
# Ajay Sharma     17801186
# Roshan Kumar    15887079
# Vijay Singh     15939950
# Name: Total_Sales, dtype: int64

# %%
data['Brand'].unique()
# Out:
# array(['Samsung', 'Intel', 'Nvidia', 'Hynix', 'Gigabyte', 'Asus', 'Dell',
#        'Seagate', 'MSI', 'Acer', 'Western Digital'], dtype=object)

# %%
data.groupby('Category')['Total_Sales'].sum()
plt.
# Out:
#   Cell In[14], line 2
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
group = data.groupby('Category')['Total_Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=group.index, y=group.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.title('Total Sales by Category')

# annotate bars
# for i, v in enumerate(group.values):
#  plt.text(i, v, fplt"{v:,}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\mks46\AppData\Local\Temp\ipykernel_18452\1117912058.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group.index, y=group.values, palette='viridis')

# %%
total_sales=data.groupby('Brand')['Total_Sales'].sum()

plt.figure(figsize=(10,6))
sns.barplot(x=total_sales.index, y=total_sales.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Brand')
plt.ylabel('Total Sales')
plt.title('Total Sales by Category')

# annotate bars
# for i, v in enumerate(total_sales.values):
#  plt.text(i, v, fplt"{v:,}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\mks46\AppData\Local\Temp\ipykernel_4360\3784826884.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_sales.index, y=total_sales.values, palette='viridis')

# %%
data['State_Code'].unique()
# Out:
# array(['AP', 'AS', 'BR', 'CG', 'JK', 'JH', 'KA', 'KL', 'MN', 'ML', 'MZ',
#        'NL', 'OR', 'PB', 'RJ', 'SK', 'TN', 'TR', 'UK', 'UP', 'WB', 'AN',
#        'CH', 'AR', 'GA', 'GJ', 'MP', 'MH', 'DH', 'DD', 'DL', 'LD', 'PY',
#        'HR', 'HP'], dtype=object)

# %%
# 1. Define the complete mapping dictionary
state_mapping = {
    'AP': 'Andhra Pradesh',        'AR': 'Arunachal Pradesh',  'AS': 'Assam',
    'BR': 'Bihar',                 'CG': 'Chhattisgarh',       'JK': 'Jammu and Kashmir',
    'JH': 'Jharkhand',             'KA': 'Karnataka',          'KL': 'Kerala',
    'MN': 'Manipur',               'ML': 'Meghalaya',          'MZ': 'Mizoram',
    'NL': 'Nagaland',              'OR': 'Odisha',             'PB': 'Punjab',
    'RJ': 'Rajasthan',             'SK': 'Sikkim',             'TN': 'Tamil Nadu',
    'TR': 'Tripura',               'UK': 'Uttarakhand',        'UP': 'Uttar Pradesh',
    'WB': 'West Bengal',           'AN': 'Andaman and Nicobar Islands',
    'CH': 'Chandigarh',            'GA': 'Goa',                'GJ': 'Gujarat',
    'MP': 'Madhya Pradesh',        'MH': 'Maharashtra',        'DH': 'Dadra and Nagar Haveli',
    'DD': 'Daman and Diu',         'DL': 'Delhi',              'LD': 'Lakshadweep',
    'PY': 'Puducherry',            'HR': 'Haryana',            'HP': 'Himachal Pradesh'
}

# 2. Apply the replacement to your DataFrame
# This creates a new 'State_Name' column while preserving the original codes
data['State_Name'] = data['State_Code'].map(state_mapping)

# 3. Check for any unmapped codes (Truth Check)
if data['State_Name'].isnull().any():
    unmapped = data[data['State_Name'].isnull()]['State_Code'].unique()
    st.warning(f"Warning: These codes were not found in the map: {unmapped}")

# %%
state_sales = data.groupby('State_Name')['Total_Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(14, 8))
sns.barplot(x=state_sales.values, y=state_sales.index, palette='viridis')
plt.xlabel('Total Sales')
plt.ylabel('State')
plt.title('Total Sales by State')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mks46\AppData\Local\Temp\ipykernel_4360\1645846547.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=state_sales.values, y=state_sales.index, palette='viridis')

# %%
data.head()
# Out:
#    Order_Number State_Code   Customer_Name Order_Date     Status  \
# 0        139374         AP     Adhir Samal  11/1/2020  Delivered
# 1        139375         AP  Dannana Jhammi  11/1/2020  Delivered
# 2        139376         AS     Vipin Kumar  11/1/2020  Delivered
# 3        139377         BR   Ranjeet Kumar  11/1/2020  Delivered
# 4        139378         CG   Sajal Singhal  11/1/2020      Order
#
#                     Product      Category     Brand  Cost_product  Sales  \
# 0                512 GB M.2           SSD   Samsung          6500   8450
# 1      RYZEN 3rd gen. 3500            CPU     Intel          8500  11050
# 2          2GB Graphic Card  Graphic Card    Nvidia          7000   9100
# 3            16 GB DDR4 RAM           RAM     Hynix          6550   8515
# 4  Standard ATX motherboard   MotherBoard  Gigabyte          7650   9945
#
#    Quantity  Total_Cost  Total_Sales  Total_Profit Assigned Supervisor  \
# 0         1        6500         8450          1950         Ajay Sharma
# 1         3       25500        33150          7650        Roshan Kumar
# 2         2       14000        18200          4200         Aarvi Gupta
# 3         3       19650        25545          5895         Vijay Singh
# 4         4       30600        39780          9180          Aadil Khan
#
#        State_Name
# 0  Andhra Pradesh
# 1  Andhra Pradesh
# 2           Assam
# 3           Bihar
# 4    Chhattisgarh
